# %% [markdown]
# <a href="https://colab.research.google.com/github/biancadsouza-21/computational-statistics/blob/main/CSSL_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
a=5
b=10
c=a+b
c
# Out:
# 15

# %%
ad_expense = [20,34,47,58,70]
sales = [4,6,10,22,35]
plt.plot(ad_expense, sales)
#plt is the name for the package

# %%
cars = [30,50,80,19,10]
accidents = [2,6,8,1,0]
plt.plot(cars, accidents)
